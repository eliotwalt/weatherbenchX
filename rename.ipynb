# %%
import os

for filename in os.listdir("scraping/scores"):
    if "_oper_" in filename:
        new_filename = filename.replace("_oper_", "_hres_init_")
        print(f"Renaming {filename} to {new_filename}")
        os.rename(os.path.join("scraping/scores", filename), os.path.join("scraping/scores", new_filename))
# Out:
# Renaming fgn_oper_mean_vs_hres_t0_1440x721_2022.nc to fgn_hres_init_mean_vs_hres_t0_1440x721_2022.nc
# Renaming fgn_oper_vs_era5_1440x721_2022.nc to fgn_hres_init_vs_era5_1440x721_2022.nc
# Renaming gencast_oper_vs_era5_1440x721_2022.nc to gencast_hres_init_vs_era5_1440x721_2022.nc
# Renaming graphcast_oper_vs_hres_t0_1440x721_2022.nc to graphcast_hres_init_vs_hres_t0_1440x721_2022.nc
# Renaming gencast_oper_mean_vs_era5_1440x721_2022.nc to gencast_hres_init_mean_vs_era5_1440x721_2022.nc
# Renaming aurora_oper_vs_hres_t0_1440x721_2022.nc to aurora_hres_init_vs_hres_t0_1440x721_2022.nc
# Renaming fgn_oper_first_member_vs_hres_t0_1440x721_2022.nc to fgn_hres_init_first_member_vs_hres_t0_1440x721_2022.nc
# Renaming fgn_oper_first_member_vs_era5_1440x721_2022.nc to fgn_hres_init_first_member_vs_era5_1440x721_2022.nc
# Renaming fgn_oper_vs_hres_t0_1440x721_2022.nc to fgn_hres_init_vs_hres_t0_1440x721_2022.nc
# ...
